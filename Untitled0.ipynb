# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepkomina/CGNS/blob/develop/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello , Sanddep" + ":" +"Welcome to Python Programming !")
# Out:
# Hello , Sanddep:Welcome to Python Programming !
