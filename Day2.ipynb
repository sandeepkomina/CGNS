# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepkomina/CGNS/blob/develop/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# int float str
# int - Integer - inf, ... -1,0 1, 2, 3 .... inf
# float - decimal - 0.1, 0.0101 , -0.1,10.29
# str - characters - "A","a", "this is a bus",":","#","@"

# %%
# Ctrl + A (Select All)
# Ctrl + / (Coment All)

# %%
# Variables

# %%
100 + 25 + 40
# Out:
# 165

# %%
100 * 7
# Out:
# 700

# %%
100 / 7
# Out:
# 14.285714285714286

# %%
100 // 7
# Out:
# 14

# %%
100 % 7
# Out:
# 2

# %%
virat = 60
rohit = 30
rahul = 10

# %%
rohit
# Out:
# 30

# %%
rahul + rohit + virat
# Out:
# 100

# %%
x = 1
y = 2
z = 3

# %%
x, y , z = 1 , 2, 3

# %%
a, b = 30 , 40

# %%
c = b + a

# %%
c
# Out:
# 70
