# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepkomina/CGNS/blob/develop/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ticket_price = 90
wallet_size = 100

# %%
# Control Structures , Conditional Statements
# Ctrl + Enter (run)
# Comparision <,>,<=.>= , !=,==

#If (condition):
#... #.to.do
#.else:
#... #.to.do

# %%
ticket_price
# Out:
# 90

# %%
if ticket_price < wallet_size:
   print("I can go to exhibition")
else:
  print("I have to go home")
# Out:
# I can go to exhibition

# %%
marks = 86

# 90+ A+
# 80+ A
# 70+ B+
# 60+ B
# 60- Fail

# if else elif

# %%
marks = 82

if(marks >= 90):
  print("A+")
elif(marks >= 80):
  print("A")
elif(marks >=70):
  print("B+")
elif(marks >=60):
  print("B")
else:
    print("Fail")
# Out:
# A

# %% [markdown]
# Here's another example using `if/else` to check voting eligibility based on age.

# %%
age = 19
voting_age = 18

if age >= voting_age:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote yet.")
